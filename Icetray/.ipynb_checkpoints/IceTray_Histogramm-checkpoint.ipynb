# %%
import numpy as np
import matplotlib.pyplot as plt
import os

print("Current folder:")
print(os.getcwd())

print("\nFiles Python can see:")
for f in os.listdir("."):
    print(repr(f))

# Datei laden
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 14,
    "axes.labelsize": 16,
    "legend.fontsize": 13
})

ice = np.loadtxt(
    "hist_10000000_100_spice_3_2_1.txt"
)

ice_left = ice[:, 0]
ice_right = ice[:, 1]
ice_counts = ice[:, 2]

ice_center = 0.5 * (ice_left + ice_right)

# same bins as Theia
theia_bin_size = 2.0
theia_t0 = 90.0

edges = (
    theia_t0
    + np.arange(len(sphereSignal) + 1) * theia_bin_size
)

# rebin IceTray into Theia bins
ice_rebinned, _ = np.histogram(
    ice_center,
    bins=edges,
    weights=ice_counts,
)

# Compare probability density
ice_density = (
    ice_rebinned
    / np.sum(ice_rebinned)
    / theia_bin_size
)

theia_density = (
    sphereSignal
    / np.sum(sphereSignal)
    / theia_bin_size
)

centers = 0.5 * (edges[:-1] + edges[1:])

plt.figure(figsize=(10, 6))

plt.step(
    centers,
    ice_density,
    where="mid",
    label="IceTray, rebinned to 2 ns",
)

plt.step(
    centers,
    theia_density,
    where="mid",
    label="Theia",
)

plt.xlabel("Zeit in ns")
plt.ylabel(r"Normierte Photonendichte [ns$^{-1}$]")
plt.xlim(95, 180)
plt.legend()
plt.grid()
plt.show()
# Out:
# Current folder:
# /home/stud/ph/go56sit/go56sit/theia/bachelorarbeit
#
# Files Python can see:
# '.ipynb_checkpoints'
# 'shader'
# '__pycache__'
# 'material_ice.py'
# 'pocam_light.py'
# '1_withsc_1layer.ipynb'
# 'I3CLSimRandomValueIceCubeFlasherTimeProfile.py'
# 'TheiaEisschicht.ipynb'
# 'generate_POCAM_flash-2.py'
# '0_nosc_1layer-Copy1.ipynb'
# 'theia_icecube.zip'
# 'Ice_layers.py'
# 'icemodel.dat'
# '.git'
# 'Icetray'
# '1_nosc_1layer.ipynb'
# '1_withsc_withlayers.ipynb'
# 'Histogramme'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 20
#      16     "axes.labelsize": 16,
#      17     "legend.fontsize": 13
#      18 })
#      19
# ---> 20 ice = np.loadtxt(
#      21     "hist_10000000_100_spice_3_2_1.txt"
#      22 )
#      23
#
# File /home/stud/ph/go56sit/go56sit/theia/.pixi/envs/default/lib/python3.14/site-packages/numpy/lib/_npyio_impl.py:1384, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1381 if isinstance(delimiter, bytes):
#    1382     delimiter = delimiter.decode('latin1')
# -> 1384 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1385             converters=converters, skiplines=skiprows, usecols=usecols,
#    1386             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1387             max_rows=max_rows, quote=quotechar)
#    1389 return arr
#
# File /home/stud/ph/go56sit/go56sit/theia/.pixi/envs/default/lib/python3.14/site-packages/numpy/lib/_npyio_impl.py:1011, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1009     fname = os.fspath(fname)
#    1010 if isinstance(fname, str):
# -> 1011     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1012     if encoding is None:
#    1013         encoding = getattr(fh, 'encoding', 'latin1')
#
# File /home/stud/ph/go56sit/go56sit/theia/.pixi/envs/default/lib/python3.14/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)    188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File /home/stud/ph/go56sit/go56sit/theia/.pixi/envs/default/lib/python3.14/site-packages/numpy/lib/_datasource.py:529, in DataSource.open(self, path, mode, encoding, newline)
#     526     return _file_openers[ext](found, mode=mode,
#     527                               encoding=encoding, newline=newline)
#     528 else:
# --> 529     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: hist_10000000_100_spice_3_2_1.txt not found.
